# %% [markdown]
# ## Importing Necessary Libraries

# %% [markdown]
# ## Loading the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\HP\OneDrive\ドキュメント\BostonHousing.csv')

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
## Summerizing the stats of the Data
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
## Check the Missing values
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# ## Explorotory Data Analysis

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219433  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311173 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.394193  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091468  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302751  0.731470
# rm      -0.219433  0.311173 -0.394193  0.091468 -0.302751  1.000000 -0.240286
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240286  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.203507 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.210718  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292794  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.357612  0.261515
# b       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128107 -0.273534
# lstat    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.615721  0.602339
# medv    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.696169 -0.376955
#
#               dis       rad       tax   ptratio         b     lstat      medv
# crim    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# chas    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# nox     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm       0.203507 -0.210718 -0.292794 -0.357612  0.128107 -0.615721  0.696169
# age     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# b        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# medv     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
import seaborn as sns
sns.pairplot(df)

# %%
plt.scatter(df['crim'],df['medv'])
plt.xlabel('Crime Rate')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df['rm'],df['medv'])
plt.xlabel('RM')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
## Ploting Regression Line
import seaborn as sns
sns.regplot(x='rm',y='medv',data=df)
plt.show()

# %%
import seaborn as sns
sns.regplot(x='lstat', y='medv',data=df)
# Out:
# <Axes: xlabel='lstat', ylabel='medv'>

# %%
sns.regplot(x='chas',y='medv',data=df)
# Out:
# <Axes: xlabel='chas', ylabel='medv'>

# %%
sns.regplot(x='ptratio', y='medv',data=df)
# Out:
# <Axes: xlabel='ptratio', ylabel='medv'>

# %% [markdown]
# #### Data Cleaning

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Creating Independent and Dependent Features

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: medv, dtype: float64

# %%
#### splitting the data into Train and Test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
X_train
# Out:
#          crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 120   0.06899   0.0  25.65     0  0.581  5.870  69.7   2.2577    2  188
# 47    0.22927   0.0   6.91     0  0.448  6.030  85.5   5.6894    3  233
# 17    0.78420   0.0   8.14     0  0.538  5.990  81.7   4.2579    4  307
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0   2.9084   24  666
# 362   3.67822   0.0  18.10     0  0.770  5.362  96.2   2.1036   24  666
# ..        ...   ...    ...   ...    ...    ...   ...      ...  ...  ...
# 110   0.10793   0.0   8.56     0  0.520  6.195  54.4   2.7778    5  384
# 275   0.09604  40.0   6.41     0  0.447  6.854  42.8   4.2673    4  254
# 353   0.01709  90.0   2.02     0  0.410  6.728  36.1  12.1265    5  187
# 440  22.05110   0.0  18.10     0  0.740  5.818  92.4   1.8662   24  666
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9   2.2110    5  384
#
#      ptratio       b  lstat
# 120     19.1  389.15  14.37
# 47      17.9  392.74  18.80
# 17      21.0  386.75  14.67
# 468     20.2  368.74  18.13
# 362     20.2  380.79  10.19
# ..       ...     ...    ...
# 110     20.9  393.49  13.00
# 275     17.6  396.90   2.98
# 353     17.0  384.46   4.50
# 440     20.2  391.45  22.11
# 106     20.9  395.67  18.66
#
# [350 rows x 13 columns]

# %%
y_train
# Out:
# 120    22.0
# 47     16.6
# 17     17.5
# 468    19.1
# 362    20.8
#        ...
# 110    21.7
# 275    32.0
# 353    30.1
# 440    10.5
# 106    19.5
# Name: medv, Length: 350, dtype: float64

# %%
#### Standardize the Dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.15128428, -0.50784842,  0.97371374, ...,  0.8345883 ,
#         -2.56864109,  0.12001028],
#        [-0.44453227, -0.50784842,  0.20929265, ...,  0.14598409,
#          0.16771201, -0.07408742],
#        [10.12332083, -0.50784842,  0.97371374, ...,  0.8345883 ,
#          0.43023201,  0.67375961],
#        ...,
#        [-0.36317941,  0.32196926, -1.0758631 , ..., -2.4707119 ,
#          0.2853038 ,  0.32837988],
#        [ 0.87044886, -0.50784842,  0.97371374, ...,  0.8345883 ,
#         -2.8122967 ,  1.53863615],
#        [-0.45305555, -0.50784842, -1.33550518, ...,  0.14598409,
#          0.39882901, -1.03886718]], shape=(151, 13))

# %%
X_train
# Out:
# array([[-0.44840151, -0.50784842,  2.0688521 , ...,  0.32961188,
#          0.34268769,  0.26843794],
#        [-0.42934304, -0.50784842, -0.64941187, ..., -0.22127149,
#          0.38324048,  0.90068267],
#        [-0.36335777, -0.50784842, -0.4709986 , ...,  1.20184388,
#          0.31557719,  0.31125361],
#        ...,
#        [-0.4545728 ,  3.22633113, -1.35871341, ..., -0.63443401,
#          0.28970925, -1.1401976 ],
#        [ 2.16543333, -0.50784842,  0.97371374, ...,  0.8345883 ,
#          0.36866858,  1.37308222],
#        [-0.43624799, -0.50784842, -0.410077  , ...,  1.15593693,
#          0.41633788,  0.88070202]], shape=(350, 13))

# %%
import pickle
pickle.dump(scaler,open('Scaling.pkl','wb'))

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# print the coefficients and intercept
print(regression.coef_)
# Out:
# [-0.81333048  1.25793481  0.55901585  0.62921378 -1.90632294  2.57817719
#   0.56191215 -2.87590127  2.74653476 -2.09048251 -2.03201533  1.20544035
#  -4.54581734]

# %%
print(regression.intercept_)
# Out:
# 22.840285714285717

# %%
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
# prediction with Test Data
y_pred = regression.predict(X_test)

# %%
y_pred
# Out:
# array([11.18470187, 23.00563404, 15.50555989, 33.91377385, 22.85033375,
#        11.52120718, 12.87909485, 19.68559436, 21.04526151, 11.33123451,
#        18.86863905, 30.14960371, -1.11832542, 25.62332993,  2.86892345,
#         8.03143995, 23.74581797, 18.48006615, 25.08802436, -6.69909852,
#        13.05721404, 18.91286419, 27.07854376, 19.68268673, 22.34432239,
#        16.60552708, 28.66835041, 26.17851266, 18.28698048, 20.9648065 ,
#        20.99274995, 30.45869773, 17.88348023, 31.45467817, 31.04568544,
#        21.85781507,  7.19466076, 23.35955087,  7.67299185, 25.28772941,
#        13.06751099, 35.87850613, 14.55527766, 30.48366917, 12.54855213,
#        28.33694316, 30.32808565, 19.98874661, 18.58460772, 13.49196425,
#        23.92954047, 33.0591127 , 16.37371772, 11.0238909 , 34.65082608,
#        33.84119359, 17.64417679, 18.519131  , 16.23822474, 27.42388838,
#        20.31971468, 40.40623824, 20.22919151,  8.17914399, 25.84915232,
#        27.38356934, 11.67432851,  7.40048488, 27.04285183, 16.64567849,
#        23.60963415, 14.40665725, 40.25260159, 28.67116535, 22.99361539,
#        23.94147544, 35.23798127, 24.24980265, 20.91360767, 15.43392463,
#        27.28906108, 27.72709976, 21.47006166, 29.39906376, 23.62974375,
#        29.33980905, 23.96158686, 20.19394735, 18.05996295, 44.36808338,
#         4.5763442 , 19.54492546, 17.21843765, 23.34149164,  6.80329983,
#        17.08154259, 30.76764064, 21.06891536, 10.78720686, 20.4811004 ,
#        24.48801448, 17.36638257, 11.96342536, 18.8007081 , 19.29750628,
#        21.9463699 , 35.5883405 , 31.44615848, 19.968172  , 20.18875558,
#        14.08016068, 11.25846629, 21.45979838, 15.59183231, 20.55569912,
#        19.46464087, 25.01497769, 23.89257441, 23.22977628, 22.60262002,
#        40.02459037, 27.23863897, 24.43315195, 30.50853388, 30.0542876 ,
#        38.56877409, 10.97200988, 22.80966069, 21.15995002, 21.64034475,
#         6.4391272 , 24.05778053, 20.70323932, 35.56053863, 10.44024763,
#        21.26056977, 32.20572251, 12.91030096, 15.21342735, 21.593391  ,
#        20.57077044, 24.72911132, 22.75876256, 34.56166809, 36.8753388 ,
#        26.7418087 , 15.70973579, 32.64803082, 30.55150854, 11.95540479,
#        25.56072489])

# %%
# plot scatter plot for prediction
plt.scatter(y_test,y_pred)

# %%
# Residuals
residuals = y_test-y_pred

# %%
residuals
# Out:
# 367    11.915298
# 76     -3.005634
# 380    -5.105560
# 160    -6.913774
# 108    -3.050334
#          ...
# 24     -0.109736
# 227    -1.048031
# 266     0.148491
# 435     1.444595
# 5       3.139275
# Name: medv, Length: 151, dtype: float64

# %%
# plot the residuals
sns.displot(residuals,kind='kde')

# %%
## Scatter plot with respect to prediction and residuals
## uniform distribution
plt.scatter(y_pred,residuals)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 18.380869507282046
# 3.0541387622304703
# 4.287291628438873

# %% [markdown]
# ## R square and adjusted R square

# %% [markdown]
# Formula
#
# R^2 = 1 - SSR/SST
#
# R^2 = coefficient of determination SSR = sum of squares of residuals SST = total sum of squares

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)

# %%
print(score)
# Out:
# 0.7509342231409273

# %% [markdown]
# ##### Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]
#
# where:
#
# R2: The R2 of the model n: The number of observations k: The number of predictor variables

# %%
1-((1-score)*(len(y_test)-1))/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.7273002443148839

# %% [markdown]
# ## New Data Prediction

# %%
np.array(X.iloc[0]).reshape(1,-1)
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
## transformation of New Data
scaler.transform(np.array(X.iloc[0]).reshape(1,-1))
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.45585344,  0.23898749, -1.31664849, -0.26521009, -0.17690896,
#          0.39541868, -0.15969257,  0.17049842, -1.01390527, -0.69939029,
#         -1.41485211,  0.43023201, -1.07169253]])

# %%
regression.predict(scaler.transform(np.array(X.iloc[0]).reshape(1,-1)))
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.32808565])

# %% [markdown]
# ## Pickling the Model for Deployment

# %%
import pickle
pickle.dump(regression,open('reg_model.pkl','wb'))

# %%
pickled_model = pickle.load(open('reg_model.pkl','rb'))

# %%
pickled_model.predict(scaler.transform(np.array(X.iloc[0]).reshape(1,-1)))
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.32808565])
